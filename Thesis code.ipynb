# %%
# === Top-10 words per SDG (multi-label) + p-values + H0 decision ===
# Graph titles show ONLY: "<label> • SDG# • Top K (n=...)" — no H0/p in the plot.

import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_selection import chi2

# NLTK stopwords
import nltk
try:
    from nltk.corpus import stopwords
    _ = stopwords.words("english")
except LookupError:
    nltk.download("stopwords")
from nltk.corpus import stopwords

# -------- CONFIG --------
FILE_PATH      = "/Users/nodiraalieva/Desktop/bachelor/cleaned.xlsx"  # <-- change if needed
TEXT_COL       = "paragraphs"                                         # text column
LABEL_COLS     = ["label_manual", "label_osdg"]                       # run both
TOP_K          = 10                                                   # top words per SDG
MIN_DF         = 1                                                    # keep rare words for tiny classes
TOKEN_MINLEN   = 3                                                    # tokens with >=3 letters
NGRAM_RANGE    = (1, 1)                                               # unigrams
ALPHA          = 0.05                                                 # significance level
USE_FDR        = True                                                 # Benjamini–Hochberg correction
# ------------------------

# Custom stopwords (extend default)
custom_stopwords = {
    "amidst", "drove", "invaluable", "convening",
    "make", "use", "section", "company", "project", "report",
    "aws","sdg","fable","achievment","agency","novs","star","ibm","wue","ghg","reductions","led","oecd","dac","gni","oda","usd","nine","pathway","thank","context","evolve","laws","ergs","able","another",
    "accurate","general","want","sds","index","subsequent","code","per","employees","held","pride",
    "dire","sdgs","multiple","widely","gap",
    "along","timely","trends"
}
ALL_STOPWORDS = set(stopwords.words("english")).union(custom_stopwords)

# ---------- Load ----------
df = pd.read_excel(FILE_PATH)
if TEXT_COL not in df.columns:
    raise ValueError(f"Text column '{TEXT_COL}' not found. Available: {list(df.columns)}")

# ---------- Clean text ----------
def clean_text(s: str) -> str:
    s = str(s).lower()
    s = re.sub(r'[^a-z\s]', ' ', s)    # keep only letters + spaces
    s = re.sub(r'\s+', ' ', s).strip()
    return s

df[TEXT_COL] = df[TEXT_COL].astype(str).apply(clean_text)

# ---------- Vectorize once on full corpus ----------
vectorizer = CountVectorizer(
    stop_words=list(ALL_STOPWORDS),
    ngram_range=NGRAM_RANGE,
    min_df=MIN_DF,
    token_pattern=rf"\b[a-z]{{{TOKEN_MINLEN},}}\b"
)
X = vectorizer.fit_transform(df[TEXT_COL])
feature_names = np.array(vectorizer.get_feature_names_out())

# ---------- Parse labels as MULTI-LABEL lists ----------
def numbers_in_label(val):
    """
    Returns ALL SDG numbers (1..17) found in a label cell.
    Tolerant: 'Goal 14', 'SDG-14', '14.0', '14, 15', emojis, odd spaces/dashes.
    """
    if pd.isna(val):
        return []
    s = str(val).lower()
    s = s.replace("\u00a0", " ")
    s = re.sub(r"\s+", " ", s)
    s = s.replace("–", "-").replace("—", "-")
    nums = re.findall(r'(?:sdg|goal)?\s*[-:]?\s*(\d{1,2})', s)
    out = []
    for num in nums:
        try:
            n = int(num)
        except ValueError:
            continue
        if 1 <= n <= 17:
            out.append(n)
    # de-duplicate preserving order
    seen, uniq = set(), []
    for n in out:
        if n not in seen:
            seen.add(n)
            uniq.append(n)
    return uniq

# ---------- Benjamini–Hochberg FDR ----------
def benjamini_hochberg(pvals: np.ndarray, alpha: float):
    """
    Returns a boolean mask of which p-values are significant under BH FDR.
    """
    m = pvals.size
    if m == 0:
        return np.array([], dtype=bool)
    order = np.argsort(pvals)
    ranked_p = pvals[order]
    thresholds = alpha * (np.arange(1, m + 1) / m)
    passed = ranked_p <= thresholds
    if not passed.any():
        return np.zeros_like(pvals, dtype=bool)
    kmax = np.where(passed)[0].max()
    cutoff = ranked_p[kmax]
    return pvals <= cutoff

# ---------- Helper: show table ----------
def show_table(df_out, title=None):
    try:
        display(df_out)  # Jupyter
    except NameError:
        if title:
            print(title)
        print(df_out.to_string(index=False))

# ---------- Run per label column ----------
for label_col in LABEL_COLS:
    if label_col not in df.columns:
        print(f"Skip: '{label_col}' not found in file. Available: {list(df.columns)}")
        continue

    print(f"\n==================== {label_col} ====================")

    # Parse to lists of SDG numbers (multi-label)
    parsed_lists = df[label_col].apply(numbers_in_label)

    # Diagnostics: count rows that contain each SDG at least once
    counts = {k: int(parsed_lists.apply(lambda lst, k=k: k in lst).sum()) for k in range(1, 18)}
    print("Rows containing each SDG (multi-label aware):")
    print({k: v for k, v in counts.items() if v > 0})
    missing = [k for k, v in counts.items() if v == 0]
    if missing:
        print("No rows contain SDGs:", missing)

    # Per SDG: one-vs-rest chi-square with p-values; graphs keep only SDG + n
    sdg_summaries = []

    for sdg_num in range(1, 18):
        y_bin = parsed_lists.apply(lambda lst, s=sdg_num: s in lst).astype(int).values
        n_pos = int(y_bin.sum())
        if n_pos == 0:
            print(f"SDG{sdg_num}: no samples, skipped.")
            continue

        # Chi2 + p-values for each feature
        chi_scores, p_values = chi2(X, y_bin)

        # Optional FDR across all features for this SDG
        if USE_FDR:
            sig_mask = benjamini_hochberg(p_values, ALPHA)
            alpha_used = f"FDR-BH {ALPHA}"
        else:
            sig_mask = p_values < ALPHA
            alpha_used = f"{ALPHA}"

        n_sig = int(sig_mask.sum())
        min_p = float(p_values.min()) if p_values.size else float("nan")
        decision = "Reject H0" if n_sig > 0 else "Fail to reject H0"

        sdg_summaries.append({
            "SDG": sdg_num,
            "n_pos": n_pos,
            "Significant_Features": n_sig,
            "Min_p_value": min_p,
            "Alpha/Criterion": alpha_used,
            "Decision": decision
        })

        # ----- TOP-K TABLE (with p-values) -----
        order_desc = np.argsort(-chi_scores)
        top_idx = order_desc[:TOP_K]
        df_top = pd.DataFrame({
            "Keyword": feature_names[top_idx],
            "Chi2": chi_scores[top_idx],
            "p_value": p_values[top_idx],
            "Significant": sig_mask[top_idx]
        }).sort_values("Chi2", ascending=False).reset_index(drop=True)

        # ----- Plot (title WITHOUT H0/p info) -----
        plt.figure(figsize=(10, 6))
        plot_order = np.argsort(df_top["Chi2"].values)
        plt.barh(
            df_top["Keyword"].values[plot_order],
            df_top["Chi2"].values[plot_order]
        )
        plt.xlabel("Chi-square score")
        plt.ylabel("Keyword")
        plt.title(f"{label_col} • SDG{sdg_num} • Top {TOP_K} keywords (n={n_pos})")
        plt.tight_layout()
        plt.show()

        # Show table
        print(f"Top {TOP_K} keywords for {label_col} SDG{sdg_num} (alpha={alpha_used})")
        show_table(df_top)

    # ----- Summary per SDG for this label_col (with p-values & decision) -----
    if sdg_summaries:
        df_summary = pd.DataFrame(sdg_summaries).sort_values("SDG")
        print(f"\n=== Summary: {label_col} (alpha={alpha_used}) ===")
        show_table(df_summary, title=f"Summary {label_col}")
# Out:
# ==================== label_manual ====================
# Rows containing each SDG (multi-label aware):
# {1: 4, 2: 7, 3: 7, 4: 20, 5: 36, 6: 9, 7: 123, 8: 68, 9: 129, 10: 28, 11: 16, 12: 206, 13: 186, 14: 7, 15: 21, 16: 49, 17: 36}
# Top 10 keywords for label_manual SDG1 (alpha=FDR-BH 0.05)
#          Keyword        Chi2       p_value  Significant
# 0        poverty  231.750000  2.475728e-52         True
# 1  incommunities  154.500000  1.800778e-35         True
# 2          rural  101.670982  6.555368e-24         True
# 3       occasion   77.250000  1.506315e-18         True
# 4   inequalities   77.250000  1.506315e-18         True
# 5        notable   77.250000  1.506315e-18         True
# 6       clothing   77.250000  1.506315e-18         True
# 7           wish   77.250000  1.506315e-18         True
# 8          sorts   77.250000  1.506315e-18         True
# 9   experiencing   77.250000  1.506315e-18         True
# Top 10 keywords for label_manual SDG2 (alpha=FDR-BH 0.05)
#          Keyword        Chi2       p_value  Significant
# 0           land  135.430937  2.657524e-31         True
# 1           food  135.430937  2.657524e-31         True
# 2      scenathon  131.142857  2.304132e-30         True
# 3      modelling   87.428571  8.737909e-21         True
# 4  incommunities   87.428571  8.737909e-21         True
# 5        compare   87.428571  8.737909e-21         True
# 6          ranks   87.428571  8.737909e-21         True
# 7        toolkit   87.428571  8.737909e-21         True
# 8         hunger   87.428571  8.737909e-21         True
# 9        finland   87.428571  8.737909e-21         True
# Top 10 keywords for label_manual SDG3 (alpha=FDR-BH 0.05)
#        Keyword        Chi2       p_value  Significant
# 0    scenathon  131.142857  2.304132e-30         True
# 1   retirement  131.142857  2.304132e-30         True
# 2       mekong   87.428571  8.737909e-21         True
# 3      compare   87.428571  8.737909e-21         True
# 4         show   87.428571  8.737909e-21         True
# 5     reversal   87.428571  8.737909e-21         True
# 6    modelling   87.428571  8.737909e-21         True
# 7  inspections   65.225210  6.680936e-16         True
# 8    upcycling   43.714286  3.799879e-11         True
# 9  secretariat   43.714286  3.799879e-11         True
# Top 10 keywords for label_manual SDG4 (alpha=FDR-BH 0.05)
#      Keyword       Chi2       p_value  Significant
# 0     career  72.891013  1.370107e-17         True
# 1       team  54.615188  1.465983e-13         True
# 2    spelman  43.950000  3.368723e-11         True
# 3    restart  43.950000  3.368723e-11         True
# 4    college  43.950000  3.368723e-11         True
# 5  community  36.684783  1.388591e-09         True
# 6  nonprofit  36.445506  1.569947e-09         True
# 7  challenge  36.445506  1.569947e-09         True
# 8    program  35.878199  2.100459e-09         True
# 9    leaders  34.364978  4.568709e-09         True
# Top 10 keywords for label_manual SDG5 (alpha=FDR-BH 0.05)
#           Keyword        Chi2       p_value  Significant
# 0             pay  107.722222  3.092160e-25         True
# 1          equity   98.682738  2.963743e-23         True
# 2           women   68.143128  1.520484e-16         True
# 3       workplace   61.871247  3.666647e-15         True
# 4          rights   56.340480  6.094765e-14         True
# 5           equal   53.861111  2.151748e-13         True
# 6           black   53.433623  2.674794e-13         True
# 7          gender   52.952712  3.416759e-13         True
# 8       workforce   47.276852  6.163583e-12         True
# 9  representation   46.166667  1.086092e-11         True
# Top 10 keywords for label_manual SDG6 (alpha=FDR-BH 0.05)
#       Keyword        Chi2        p_value  Significant
# 0       water  599.451930  2.202971e-132         True
# 1     cooling  262.281433   5.460425e-59         True
# 2       reuse  202.666667   5.469206e-46         True
# 3      newest  135.111111   3.121998e-31         True
# 4     designs  106.494810   5.744274e-25         True
# 5  boundaries  101.333333   7.773655e-24         True
# 6   scenathon  101.333333   7.773655e-24         True
# 7     factory  101.333333   7.773655e-24         True
# 8  datacenter   95.422149   1.538230e-22         True
# 9   treatment   74.507401   6.041136e-18         True
# Top 10 keywords for label_manual SDG7 (alpha=FDR-BH 0.05)
#          Keyword        Chi2       p_value  Significant
# 0      emissions  194.833424  2.801346e-44         True
# 1         carbon  165.368855  7.598624e-38         True
# 2         energy   48.201074  3.846775e-12         True
# 3      reduction   46.013212  1.174582e-11         True
# 4       software   39.851872  2.739715e-10         True
# 5         safety   34.324909  4.663744e-09         True
# 6           team   29.131579  6.762568e-08         True
# 7         reduce   28.730146  8.319848e-08         True
# 8          scope   27.780505  1.358885e-07         True
# 9  semiconductor   22.948341  1.664138e-06         True
# Top 10 keywords for label_manual SDG8 (alpha=FDR-BH 0.05)
#      Keyword        Chi2       p_value  Significant
# 0     safety  119.973806  6.410155e-28         True
# 1     equity   54.044118  1.960381e-13         True
# 2        pay   50.441176  1.227906e-12         True
# 3      labor   50.441176  1.227906e-12         True
# 4    culture   50.134895  1.435318e-12         True
# 5     carbon   49.959184  1.569776e-12         True
# 6       team   43.398181  4.466032e-11         True
# 7     career   43.235294  4.853720e-11         True
# 8  inclusive   40.705417  1.769958e-10         True
# 9     rights   37.200484  1.065873e-09         True
# Top 10 keywords for label_manual SDG9 (alpha=FDR-BH 0.05)
#           Keyword       Chi2       p_value  Significant
# 0          safety  37.959538  7.222709e-10         True
# 1       microsoft  37.426923  9.490296e-10         True
# 2        software  24.230699  8.545921e-07         True
# 3      technology  22.404907  2.208091e-06         True
# 4           cloud  21.395349  3.736766e-06         True
# 5       countries  20.804101  5.087391e-06         True
# 6  sustainability  20.798613  5.101990e-06         True
# 7   international  17.768016  2.495431e-05         True
# 8           based  16.698237  4.382171e-05         True
# 9           intel  16.216910  5.648764e-05         True
# Top 10 keywords for label_manual SDG10 (alpha=FDR-BH 0.05)
#           Keyword       Chi2       p_value  Significant
# 0           labor  83.320811  6.976131e-20         True
# 1          forced  50.892857  9.754793e-13         True
# 2          equity  48.000075  4.262028e-12         True
# 3         workers  42.852694  5.902074e-11         True
# 4  representation  40.760422  1.720832e-10         True
# 5            vote  40.760422  1.720832e-10         True
# 6             pay  39.926101  2.637550e-10         True
# 7       inclusive  33.107268  8.721211e-09         True
# 8           donor  30.535714  3.277766e-08         True
# 9         refugee  30.535714  3.277766e-08         True
# Top 10 keywords for label_manual SDG11 (alpha=FDR-BH 0.05)
#        Keyword       Chi2       p_value  Significant
# 0      drivers  92.812500  5.749090e-22         True
# 1        reuse  75.686062  3.325467e-18         True
# 2     incident  74.250000  6.882482e-18         True
# 3    behaviors  57.810774  2.885847e-14         True
# 4  teleworking  55.687500  8.495677e-14         True
# 5    employers  55.687500  8.495677e-14         True
# 6       safety  51.485723  7.211967e-13         True
# 7    commuting  46.869248  7.588413e-12         True
# 8     patterns  40.279093  2.201524e-10         True
# 9       unsafe  40.279093  2.201524e-10         True
# Top 10 keywords for label_manual SDG12 (alpha=FDR-BH 0.05)
#          Keyword       Chi2       p_value  Significant
# 0         carbon  81.734886  1.556221e-19         True
# 1      emissions  69.334170  8.311706e-17         True
# 2           team  46.153057  1.093662e-11         True
# 3           dell  38.503323  5.466052e-10         True
# 4        members  38.007844  7.046080e-10         True
# 5      countries  30.936948  2.665486e-08         True
# 6         energy  29.606796  5.291907e-08         True
# 7         fiscal  29.575572  5.377844e-08         True
# 8         equity  28.878505  7.706340e-08         True
# 9  international  27.987787  1.220835e-07         True
# Top 10 keywords for label_manual SDG13 (alpha=FDR-BH 0.05)
#      Keyword        Chi2       p_value  Significant
# 0  emissions  114.099381  1.239385e-26         True
# 1     carbon  109.809515  1.078744e-25         True
# 2     safety   75.372639  3.897537e-18         True
# 3       team   51.947583  5.700218e-13         True
# 4       dell   36.873785  1.260291e-09         True
# 5    climate   35.533291  2.507285e-09         True
# 6  microsoft   34.263579  4.813055e-09         True
# 7    culture   33.685039  6.479712e-09         True
# 8   training   33.186223  8.374174e-09         True
# 9    members   32.370912  1.273790e-08         True
# Top 10 keywords for label_manual SDG14 (alpha=FDR-BH 0.05)
#            Keyword        Chi2       p_value  Significant
# 0  transformations  131.142857  2.304132e-30         True
# 1             land   97.837815  4.540924e-23         True
# 2             show   87.428571  8.737909e-21         True
# 3            paper   87.428571  8.737909e-21         True
# 4         reversal   87.428571  8.737909e-21         True
# 5             food   66.342982  3.789056e-16         True
# 6      achievement   62.605742  2.525161e-15         True
# 7             loss   56.960006  4.447655e-14         True
# 8            earth   53.074385  3.211532e-13         True
# 9            icraf   43.714286  3.799879e-11         True
# Top 10 keywords for label_manual SDG15 (alpha=FDR-BH 0.05)
#          Keyword        Chi2       p_value  Significant
# 0       wildlife  139.047619  4.300138e-32         True
# 1  deforestation  125.142857  4.735951e-29         True
# 2           land  106.375125  6.101888e-25         True
# 3       nitrogen   85.819243  1.971582e-20         True
# 4   biodiversity   85.819243  1.971582e-20         True
# 5         forest   69.523810  7.549763e-17         True
# 6           soil   69.523810  7.549763e-17         True
# 7          water   64.697689  8.731720e-16         True
# 8      satellite   55.619048  8.796714e-14         True
# 9         google   47.906719  4.469872e-12         True
# Top 10 keywords for label_manual SDG16 (alpha=FDR-BH 0.05)
#       Keyword       Chi2       p_value  Significant
# 0       labor  63.194016  1.873166e-15         True
# 1      rights  47.033813  6.977254e-12         True
# 2        team  42.843462  5.929994e-11         True
# 3    feedback  37.792538  7.868218e-10         True
# 4     culture  35.610178  2.410249e-09         True
# 5      groups  34.796278  3.660726e-09         True
# 6       human  32.470075  1.210421e-08         True
# 7  connection  32.326531  1.303218e-08         True
# 8   emissions  31.924242  1.603040e-08         True
# 9       month  31.355875  2.148077e-08         True
# Top 10 keywords for label_manual SDG17 (alpha=FDR-BH 0.05)
#          Keyword       Chi2       p_value  Significant
# 0  international  89.692472  2.782116e-21         True
# 1        nations  53.433623  2.674794e-13         True
# 2         states  53.433623  2.674794e-13         True
# 3         united  47.534973  5.403135e-12         True
# 4   organization  47.276852  6.163583e-12         True
# 5           vote  46.166667  1.086092e-11         True
# 6           fund  38.321364  6.000214e-10         True
# 7          union  37.875709  7.539820e-10         True
# 8       proceeds  31.689982  1.808527e-08         True
# 9       military  31.689982  1.808527e-08         True
# === Summary: label_manual (alpha=FDR-BH 0.05) ===
#     SDG  n_pos  Significant_Features    Min_p_value Alpha/Criterion   Decision
# 0     1      4                   108   2.475728e-52     FDR-BH 0.05  Reject H0
# 1     2      7                   213   2.657524e-31     FDR-BH 0.05  Reject H0
# 2     3      7                   118   2.304132e-30     FDR-BH 0.05  Reject H0
# 3     4     20                   203   1.370107e-17     FDR-BH 0.05  Reject H0
# 4     5     36                   130   3.092160e-25     FDR-BH 0.05  Reject H0
# 5     6      9                   187  2.202971e-132     FDR-BH 0.05  Reject H0
# 6     7    123                    41   2.801346e-44     FDR-BH 0.05  Reject H0
# 7     8     68                    92   6.410155e-28     FDR-BH 0.05  Reject H0
# 8     9    129                    14   7.222709e-10     FDR-BH 0.05  Reject H0
# 9    10     28                   232   6.976131e-20     FDR-BH 0.05  Reject H0
# 10   11     16                   196   5.749090e-22     FDR-BH 0.05  Reject H0
# 11   12    206                    39   1.556221e-19     FDR-BH 0.05  Reject H0
# 12   13    186                    40   1.239385e-26     FDR-BH 0.05  Reject H0
# 13   14      7                   137   2.304132e-30     FDR-BH 0.05  Reject H0
# 14   15     21                   309   4.300138e-32     FDR-BH 0.05  Reject H0
# 15   16     49                   129   1.873166e-15     FDR-BH 0.05  Reject H0
# 16   17     36                    74   2.782116e-21     FDR-BH 0.05  Reject H0
# ==================== label_osdg ====================
# Rows containing each SDG (multi-label aware):
# {1: 3, 2: 8, 3: 1, 4: 15, 5: 9, 6: 5, 7: 43, 8: 14, 9: 8, 10: 4, 11: 3, 12: 10, 13: 96, 15: 11, 16: 28, 17: 1}
# No rows contain SDGs: [14]
# Top 10 keywords for label_osdg SDG1 (alpha=FDR-BH 0.05)
#      Keyword        Chi2       p_value  Significant
# 0    poverty  310.000000  2.183859e-69         True
# 1     grants  206.666667  7.330469e-47         True
# 2  secretary  103.333333  2.832474e-24         True
# 3        war  103.333333  2.832474e-24         True
# 4      grave  103.333333  2.832474e-24         True
# 5     plenty  103.333333  2.832474e-24         True
# 6   agencies  103.333333  2.832474e-24         True
# 7   applauds  103.333333  2.832474e-24         True
# 8   occasion  103.333333  2.832474e-24         True
# 9      sorts  103.333333  2.832474e-24         True
# Top 10 keywords for label_osdg SDG2 (alpha=FDR-BH 0.05)
#         Keyword        Chi2       p_value  Significant
# 0          land  155.285683  1.212729e-35         True
# 1          food  117.186913  2.612496e-27         True
# 2    boundaries  114.375000  1.078553e-26         True
# 3     scenathon  114.375000  1.078553e-26         True
# 4      security   99.017486  2.502820e-23         True
# 5      nitrogen   90.378074  1.967343e-21         True
# 6  biodiversity   90.378074  1.967343e-21         True
# 7       compare   76.250000  2.499327e-18         True
# 8         ranks   76.250000  2.499327e-18         True
# 9        bottom   76.250000  2.499327e-18         True
# Top 10 keywords for label_osdg SDG3 (alpha=FDR-BH 0.05)
#           Keyword        Chi2        p_value  Significant
# 0        campaign  624.000000  1.008733e-137         True
# 1        speakers  312.000000   8.008342e-70         True
# 2      multimedia  312.000000   8.008342e-70         True
# 3         traffic  312.000000   8.008342e-70         True
# 4           round  155.001603   1.399083e-35         True
# 5         virtual  155.001603   1.399083e-35         True
# 6           class  155.001603   1.399083e-35         True
# 7        wellness  155.001603   1.399083e-35         True
# 8            read  155.001603   1.399083e-35         True
# 9  communications  102.670940   3.957066e-24         True
# Top 10 keywords for label_osdg SDG4 (alpha=FDR-BH 0.05)
#         Keyword        Chi2       p_value  Significant
# 0        safety  170.161861  6.820475e-39         True
# 1      training  120.179040  5.780125e-28         True
# 2      coaching  119.200000  9.468492e-28         True
# 3      affinity   81.119500  2.124730e-19         True
# 4       courses   43.212584  4.910385e-11         True
# 5  professional   43.212584  4.910385e-11         True
# 6    ergonomics   43.212584  4.910385e-11         True
# 7       learned   39.733333  2.911143e-10         True
# 8     chemistry   39.733333  2.911143e-10         True
# 9      civilian   39.733333  2.911143e-10         True
# Top 10 keywords for label_osdg SDG5 (alpha=FDR-BH 0.05)
#       Keyword        Chi2       p_value  Significant
# 0         pay  405.891004  2.874487e-90         True
# 1      equity  319.484430  1.875875e-71         True
# 2      gender  304.000000  4.429197e-68         True
# 3       month  212.989620  3.059404e-48         True
# 4  disability  149.014803  2.846460e-34         True
# 5    affinity  139.079008  4.232704e-32         True
# 6    heritage  135.111111  3.121998e-31         True
# 7  regardless  101.333333  7.773655e-24         True
# 8      skills   95.719321  1.323821e-22         True
# 9         day   88.344564  5.499052e-21         True
# Top 10 keywords for label_osdg SDG6 (alpha=FDR-BH 0.05)
#        Keyword        Chi2       p_value  Significant
# 0        reuse  255.002706  2.107885e-57         True
# 1        water  212.173876  4.608918e-48         True
# 2   wastewater  184.800000  4.339701e-42         True
# 3    treatment  137.104058  1.144287e-31         True
# 4    frontline  123.200000  1.260777e-28         True
# 5         ejdf  123.200000  1.260777e-28         True
# 6  achievement   89.424351  3.185909e-21         True
# 7          air   78.485750  8.057739e-19         True
# 8     freezers   61.600000  4.208186e-15         True
# 9          nox   61.600000  4.208186e-15         True
# Top 10 keywords for label_osdg SDG7 (alpha=FDR-BH 0.05)
#        Keyword        Chi2       p_value  Significant
# 0       energy  227.129667  2.519597e-51         True
# 1       carbon   79.852007  4.035302e-19         True
# 2     embodied   79.625010  4.526591e-19         True
# 3    renewable   55.278749  1.045933e-13         True
# 4     building   41.955558  9.337161e-11         True
# 5       reduce   41.723521  1.051365e-10         True
# 6    materials   40.275983  2.205031e-10         True
# 7  electricity   31.145717  2.393669e-08         True
# 8      centers   26.710775  2.363001e-07         True
# 9     concrete   25.335444  4.817743e-07         True
# Top 10 keywords for label_osdg SDG8 (alpha=FDR-BH 0.05)
#         Keyword        Chi2       p_value  Significant
# 0           pay  255.957426  1.305350e-57         True
# 1        equity  200.256665  1.835786e-45         True
# 2     workforce  173.917596  1.031763e-39         True
# 3      linkedin  171.197539  4.051512e-39         True
# 4       capital  139.695831  3.102622e-32         True
# 5         green  104.737975  1.394035e-24         True
# 6        gender   81.475394  1.774573e-19         True
# 7        skills   77.615862  1.251609e-18         True
# 8       economy   72.160631  1.983742e-17         True
# 9  compensation   64.071429  1.199891e-15         True
# Top 10 keywords for label_osdg SDG9 (alpha=FDR-BH 0.05)
#          Keyword       Chi2       p_value  Significant
# 0  manufacturers  84.287807  4.277450e-20         True
# 1            poc  76.250000  2.499327e-18         True
# 2        toolkit  76.250000  2.499327e-18         True
# 3      tripkicks  76.250000  2.499327e-18         True
# 4         advito  76.250000  2.499327e-18         True
# 5        display  54.226844  1.786298e-13         True
# 6     annualized  49.508743  1.974896e-12         True
# 7       suggests  38.125000  6.635448e-10         True
# 8        sensing  38.125000  6.635448e-10         True
# 9  contextualize  38.125000  6.635448e-10         True
# Top 10 keywords for label_osdg SDG10 (alpha=FDR-BH 0.05)
#        Keyword        Chi2        p_value  Significant
# 0          pay  930.661639  2.120663e-204         True
# 1       equity  736.807767  2.964161e-162         True
# 2        equal  173.159501   1.510554e-39         True
# 3    migration  172.315736   2.308905e-39         True
# 4       fairly  154.500000   1.800778e-35         True
# 5  statistical  154.500000   1.800778e-35         True
# 6       firmly  154.500000   1.800778e-35         True
# 7   conducting  154.500000   1.800778e-35         True
# 8      migrant  154.500000   1.800778e-35         True
# 9          iom  154.500000   1.800778e-35         True
# Top 10 keywords for label_osdg SDG11 (alpha=FDR-BH 0.05)
#       Keyword        Chi2        p_value  Significant
# 0       month  658.137204  3.797050e-145         True
# 1    heritage  413.333333   6.895289e-92         True
# 2         day  290.510459   3.848860e-65         True
# 3       trees  231.002419   3.603576e-52         True
# 4   hebersham  206.666667   7.330469e-47         True
# 5  connection  152.014516   6.290039e-35         True
# 6    planting  136.447670   1.592558e-31         True
# 7    showcase  136.447670   1.592558e-31         True
# 8       daily  136.447670   1.592558e-31         True
# 9    hispanic  136.447670   1.592558e-31         True
# Top 10 keywords for label_osdg SDG12 (alpha=FDR-BH 0.05)
#          Keyword        Chi2       p_value  Significant
# 0          reuse  124.588834  6.261242e-29         True
# 1          waste  117.960424  1.768824e-27         True
# 2          water   66.461640  3.567694e-16         True
# 3      recycling   60.600000  6.993401e-15         True
# 4  incommunities   60.600000  6.993401e-15         True
# 5           leed   60.600000  6.993401e-15         True
# 6     regulation   60.600000  6.993401e-15         True
# 7     functional   60.600000  6.993401e-15         True
# 8         pilots   60.600000  6.993401e-15         True
# 9      estimated   60.600000  6.993401e-15         True
# Top 10 keywords for label_osdg SDG13 (alpha=FDR-BH 0.05)
#      Keyword        Chi2       p_value  Significant
# 0  emissions  274.766272  1.037896e-61         True
# 1     carbon  179.087567  7.667330e-41         True
# 2      scope   66.214459  4.044350e-16         True
# 3    climate   40.216462  2.273246e-10         True
# 4     reduce   36.411486  1.597589e-09         True
# 5  reduction   35.930881  2.044426e-09         True
# 6     nature   32.182886  1.403213e-08         True
# 7    science   29.177772  6.603242e-08         True
# 8      based   28.903397  7.607936e-08         True
# 9  solutions   27.521572  1.553521e-07         True
# SDG14: no samples, skipped.
# Top 10 keywords for label_osdg SDG15 (alpha=FDR-BH 0.05)
#          Keyword        Chi2       p_value  Significant
# 0       wildlife  274.545455  1.159517e-61         True
# 1  deforestation  193.458593  5.590232e-44         True
# 2          trees  109.818182  1.074037e-25         True
# 3        planted  109.818182  1.074037e-25         True
# 4           tree  109.818182  1.074037e-25         True
# 5          urban   86.261830  1.576217e-20         True
# 6  reforestation   82.363636  1.132177e-19         True
# 7       planting   82.363636  1.132177e-19         True
# 8         online   76.472908  2.232549e-18         True
# 9         google   76.388941  2.329522e-18         True
# Top 10 keywords for label_osdg SDG16 (alpha=FDR-BH 0.05)
#        Keyword        Chi2       p_value  Significant
# 0     wildlife  101.785714  6.186470e-24         True
# 1  inspections   61.982155  3.465838e-15         True
# 2       rights   61.354219  4.767686e-15         True
# 3  trafficking   61.071429  5.504116e-15         True
# 4        human   44.516581  2.522121e-11         True
# 5        rules   40.714286  1.761944e-10         True
# 6       visits   40.714286  1.761944e-10         True
# 7       policy   40.092110  2.422655e-10         True
# 8      conduct   36.812531  1.300516e-09         True
# 9    coalition   33.551038  6.941831e-09         True
# Top 10 keywords for label_osdg SDG17 (alpha=FDR-BH 0.05)
#         Keyword        Chi2       p_value  Significant
# 0      wetlands  312.000000  8.008342e-70         True
# 1           dhi  312.000000  8.008342e-70         True
# 2          unep  155.001603  1.399083e-35         True
# 3  specifically  102.670940  3.957066e-24         True
# 4      selected  102.670940  3.957066e-24         True
# 5   accelerated  102.670940  3.957066e-24         True
# 6       machine  102.670940  3.957066e-24         True
# 7    accurately   76.507212  2.194103e-18         True
# 8         among   50.346688  1.288474e-12         True
# 9       million   46.307821  1.010598e-11         True
# === Summary: label_osdg (alpha=FDR-BH 0.05) ===
#     SDG  n_pos  Significant_Features    Min_p_value Alpha/Criterion   Decision
# 0     1      3                    82   2.183859e-69     FDR-BH 0.05  Reject H0
# 1     2      8                   206   1.212729e-35     FDR-BH 0.05  Reject H0
# 2     3      1                    27  1.008733e-137     FDR-BH 0.05  Reject H0
# 3     4     15                   115   6.820475e-39     FDR-BH 0.05  Reject H0
# 4     5      9                   188   2.874487e-90     FDR-BH 0.05  Reject H0
# 5     6      5                   124   2.107885e-57     FDR-BH 0.05  Reject H0
# 6     7     43                    79   2.519597e-51     FDR-BH 0.05  Reject H0
# 7     8     14                   189   1.305350e-57     FDR-BH 0.05  Reject H0
# 8     9      8                   106   4.277450e-20     FDR-BH 0.05  Reject H0
# 9    10      4                    99  2.120663e-204     FDR-BH 0.05  Reject H0
# 10   11      3                   116  3.797050e-145     FDR-BH 0.05  Reject H0
# 11   12     10                   170   6.261242e-29     FDR-BH 0.05  Reject H0
# 12   13     96                    45   1.037896e-61     FDR-BH 0.05  Reject H0
# 13   15     11                   207   1.159517e-61     FDR-BH 0.05  Reject H0
# 14   16     28                   260   6.186470e-24     FDR-BH 0.05  Reject H0
# 15   17      1                    31   8.008342e-70     FDR-BH 0.05  Reject H0
